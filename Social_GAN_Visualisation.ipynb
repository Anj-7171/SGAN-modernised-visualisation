# %%
# !git clone https://github.com/Anj-7171/SGAN-modernised.git
# Out:
# Cloning into 'SGAN-modernised'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 51 (delta 10), reused 51 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (51/51), 232.79 KiB | 1.31 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
# %cd /content/SGAN-modernised
# Out:
# /content/SGAN-modernised

# %%
# !pip install numpy scipy matplotlib tqdm

# %%
# !grep -rn ".cuda()" .

# %%
# !ls
# Out:
# images	 MODEL_ZOO.md  requirements.txt  sgan
# LICENSE  README.md     scripts		 TRAINING.md

# %%
# !mkdir datasets

# %%
# !unzip -q sgan-models.zip
# !unzip -q sgan-p-models.zip
# !rm sgan-models.zip sgan-p-models.zip

# %%
# !ls sgan-models
# Out:
# eth_12_model.pt    hotel_8_model.pt  zara1_12_model.pt	zara2_8_model.pt
# eth_8_model.pt	   univ_12_model.pt  zara1_8_model.pt
# hotel_12_model.pt  univ_8_model.pt   zara2_12_model.pt

# %%
# !unzip -q datasets/datasets.zip -d datasets
# !rm datasets/datasets.zip

# %%
# !mv datasets/datasets/* datasets/
# !rm -r datasets/datasets

# %%
# !ls datasets
# Out:
# eth  hotel  raw  univ  zara1  zara2

# %%
# Set PYTHONPATH in Colab
import os
os.environ['PYTHONPATH'] = '/content/SGAN-modernised'

# Run the evaluation script
# !python scripts/evaluate_model.py --model_path sgan-models/eth_12_model.pt
# Out:
# Dataset: eth, Pred Len: 12, ADE: 0.70, FDE: 1.28

# %%
from visualisation import plot_trajectories

# %%
# !ls
# Out:
# datasets  MODEL_ZOO.md	requirements.txt  sgan-models	 visualisation.py
# images	  __pycache__	scripts		  sgan-p-models
# LICENSE   README.md	sgan		  TRAINING.md

# %%
# %matplotlib inline

# %%
# !python scripts/evaluate_model.py --model_path sgan-models/eth_12_model.pt
# Out:
# Dataset: eth, Pred Len: 12, ADE: 0.69, FDE: 1.29

# %%
# !ls images
# Out:
# 2.gif  3.gif  full_scene.png  model.png  ped0.png  sample_plot.png

# %%
from PIL import Image
display(Image.open("images/full_scene.png"))
display(Image.open("images/ped0.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=621x624>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=609x624>

# %%
# %cd /content/SGAN-modernised
# Out:
# /content/SGAN-modernised

# %%
# !git remote -v
# Out:
# origin	https://github.com/Anj-7171/SGAN-modernised.git (fetch)
# origin	https://github.com/Anj-7171/SGAN-modernised.git (push)

# %%
# !git remote remove origin

# %%
# !git remote -v

# %%
# !git remote add origin https://github.com/Anj-7171/SGAN-modernised-visualisation.git

# %%
# !git add .

# %%
# !git config --global user.name "Anj-7171"
# !git config --global user.email "anjanascript7@gmail.com"

# %%
# !git remote remove origin
# !git remote add origin https://Anj-7171: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@github.com/Anj-7171/SGAN-modernised-visualisation.git

# %%
# !git remote -v
# Out:
# origin	https://Anj-7171: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@github.com/Anj-7171/SGAN-modernised-visualisation.git (fetch)
# origin	https://Anj-7171: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@github.com/Anj-7171/SGAN-modernised-visualisation.git (push)

# %%
# !git push -u origin main --force
# Out:
# Enumerating objects: 143, done.
# Counting objects: 100% (143/143), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (129/129), done.
# Writing objects: 100% (143/143), 4.80 MiB | 5.10 MiB/s, done.
# Total 143 (delta 32), reused 41 (delta 10), pack-reused 0
# remote: Resolving deltas: 100% (32/32), done.
# To https://github.com/Anj-7171/SGAN-modernised-visualisation.git
#  + 5e1acf8...b9f35f8 main -> main (forced update)
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !git remote set-url origin https://github.com/Anj-7171/SGAN-modernised-visualisation.git
